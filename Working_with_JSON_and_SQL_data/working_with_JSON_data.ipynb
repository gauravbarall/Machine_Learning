# %%
import pandas as pd

# %% [markdown]
# # Loading json from local file

# %%
df = pd.read_json("train.json")
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Loading from url

# %%
df = pd.read_json("https://fake-json-api.mock.beeceptor.com/users")
df
# Out:
#    id                                               name  \
# 0   1                                    Lincoln Spencer
# 1   2  Winifred Faker Attribute Error: person.astName...
# 2   3                                         Dion Bogan
# 3   4                                     Daryl Reynolds
# 4   5                                     Alyce Connelly
# 5   6                                      Nelda McGlynn
# 6   7                                     Tierra Quitzon
# 7   8                                       Tyshawn Lowe
# 8   9                                          Mara Haag
# 9  10                                     Emile Cummings
#
#                 company           username                            email  \
# 0      Nikolaus - Marks   Vicenta_Senger62  Winona_Pfannerstill@hotmail.com
# 1        Vandervort Inc            Leola81         Chaz_Aufderhar@yahoo.com
# 2   Rosenbaum - Smitham  Bertram_Reichel21         Jules_Herman70@gmail.com
# ...
