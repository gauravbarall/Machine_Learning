# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('weight-height.csv')

# %%
df['Height'].head()
# Out:
# 0    73.847017
# 1    68.781904
# 2    74.110105
# 3    71.730978
# 4    69.881796
# Name: Height, dtype: float64

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
df.shape
# Out:
# (10000, 3)

# %%
sns.boxplot(df['Height'])
# Out:
# <Axes: >

# %%
# boundaries
upper_limit = df['Height'].quantile(0.99)
lower_limit = df['Height'].quantile(0.01)

upper_limit, lower_limit
# Out:
# (74.7857900583366, 58.13441158671655)

# %% [markdown]
# ## Trimming

# %%
new_df = df[ (df['Height'] >= 58.13) & (df['Height'] <= 74.78)]

# %%
new_df['Height'].describe()
# Out:
# count    9799.000000
# mean       66.363507
# std         3.644267
# min        58.134496
# 25%        63.577147
# 50%        66.317899
# 75%        69.119859
# max        74.767447
# Name: Height, dtype: float64

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize= (12,5))
ax1.set_title('Before removal of outlier')
ax2.set_title('After removal of outlier')

sns.histplot(df['Height'], kde=True, stat='density', ax=ax1)
sns.histplot(new_df['Height'], kde=True, stat='density', ax=ax2)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: title={'center': 'After removal of outlier'}, xlabel='Height', ylabel='Density'>

# %%
sns.boxplot(new_df['Height'])
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %% [markdown]
# ## Capping ===> Winsorization

# %%
df['Height'] = np.where(
    df['Height'] >= upper_limit,
    upper_limit,
    np.where(
        df['Height'] <= lower_limit,
        lower_limit,
        df['Height']
    )
)

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.366281
# std          3.795717
# min         58.134412
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         74.785790
# Name: Height, dtype: float64

# %%
sns.boxplot(df['Height'])
# Out:
# <Axes: >

# %%
sns.histplot(df['Height'], kde=True, stat='density')
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Height', ylabel='Density'>
